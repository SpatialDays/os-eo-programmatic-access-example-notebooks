# %%
# !pip install pystac
# !pip install pystac-client
# Out:
# Requirement already satisfied: pystac in ./env/lib/python3.10/site-packages (1.8.3)
# Requirement already satisfied: python-dateutil>=2.7.0 in ./env/lib/python3.10/site-packages (from pystac) (2.8.2)
# Requirement already satisfied: six>=1.5 in ./env/lib/python3.10/site-packages (from python-dateutil>=2.7.0->pystac) (1.16.0)
# Requirement already satisfied: pystac-client in ./env/lib/python3.10/site-packages (0.7.5)
# Requirement already satisfied: requests>=2.28.2 in ./env/lib/python3.10/site-packages (from pystac-client) (2.31.0)
# Requirement already satisfied: pystac[validation]>=1.8.2 in ./env/lib/python3.10/site-packages (from pystac-client) (1.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./env/lib/python3.10/site-packages (from pystac-client) (2.8.2)
# Requirement already satisfied: jsonschema<4.18,>=4.0.1 in ./env/lib/python3.10/site-packages (from pystac[validation]>=1.8.2->pystac-client) (4.17.3)
# Requirement already satisfied: six>=1.5 in ./env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pystac-client) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./env/lib/python3.10/site-packages (from requests>=2.28.2->pystac-client) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in ./env/lib/python3.10/site-packages (from requests>=2.28.2->pystac-client) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./env/lib/python3.10/site-packages (from requests>=2.28.2->pystac-client) (2.0.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./env/lib/python3.10/site-packages (from requests>=2.28.2->pystac-client) (3.2.0)
# Requirement already satisfied: attrs>=17.4.0 in ./env/lib/python3.10/site-packages (from jsonschema<4.18,>=4.0.1->pystac[validation]>=1.8.2->pystac-client) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in ./env/lib/python3.10/site-packages (from jsonschema<4.18,>=4.0.1->pystac[validation]>=1.8.2->pystac-client) (0.19.3)

# %%
# Import PySTAC to use it in the notebook
import pystac
import pystac_client

# %%
# Credentials and details for Azure APIM
APIM_STAC_URL = "https://os-eo-platform-rg-prod-apim.azure-api.net/stac/"
APIM_AUTH_TOKEN = "d208843ea70a43d29416315322dc3228"
# Create AUTH Header object
auth_headers = {"ocp-apim-subscription-key": APIM_AUTH_TOKEN}

# %%
# Create Pystac client object
client: pystac_client.client.Client = pystac_client.Client.from_file(
    APIM_STAC_URL, headers=auth_headers
)

# %%
from typing import List

collections: List[pystac.Collection] = list(client.get_collections())

# Print the number of collections
print(f"Number of collections: {len(collections)}")
for collection in collections:
    print(collection.id)
# Out:
# Number of collections: 6
# landsat-c2-l2
# sentinel-2-l2a
# os_heightstore_dtm1m
# os_heightstore_dsm1m
# os_heightstore_dsm25cm
# os_rgbi

# %%
COLLECTION_ID = "os_rgbi"
ITEM_ID = "ffd85f2a-c3a1-4c81-9b25-7b059ba1f724"
# Get the item from the wanted collection
collection: pystac.Collection = client.get_collection(COLLECTION_ID)
item: pystac.Item = collection.get_item(ITEM_ID)

# %%
# print all atributes of the item
for i in dir(item):
    if i[0] == "_":
        continue
    print(i)
# Out:
# STAC_OBJECT_TYPE
# add_asset
# add_derived_from
# add_link
# add_links
# assets
# bbox
# clear_links
# clone
# collection_id
# common_metadata
# datetime
# delete_asset
# extra_fields
# from_dict
# from_file
# full_copy
# geometry
# get_assets
# get_collection
# get_datetime
# get_derived_from
# get_links
# get_parent
# get_root
# get_root_link
# get_self_href
# get_single_link
# get_stac_objects
# id
# links
# make_asset_hrefs_absolute
# make_asset_hrefs_relative
# matches_object_type
# properties
# remove_derived_from
# remove_hierarchical_links
# remove_links
# resolve_links
# save_object
# self_href
# set_collection
# set_datetime
# set_parent
# set_root
# set_self_href
# stac_extensions
# target_in_hierarchy
# to_dict
# validate

# %%
# pretty print the item
import json

print(json.dumps(item.to_dict(), indent=4))
# Out:
# {
#     "type": "Feature",
#     "stac_version": "1.0.0",
#     "id": "ffd85f2a-c3a1-4c81-9b25-7b059ba1f724",
#     "properties": {
#         "bulk-upload-system-metadata:original-metadata-location": "https://oseoinfraprodstrgacc.blob.core.windows.net/rss-rgbi25cm16bittiff-raw/data/incremental/2023/07/13/15/LOTH01_23/NT2267.json",
#         "datetime": "2023-06-15T00:00:00Z",
#         "gsd": 0.25,
#         "license": "proprietary",
#         "os-rgbi:acquired-by": "Ordnance Survey",
#         "os-rgbi:flying-block": "LOTH01_23",
#         "os-rgbi:imagery-control-method": "GPS and OSTN02",
#         "os-rgbi:imagery-type": "Core Tile",
#         "os-rgbi:lens-focal-length": [
#             100.5
#         ],
#         "os-rgbi:metadata-date": "2023-07-10",
#         "os-rgbi:nominal-flying-height": 3909,
#         "os-rgbi:tile-count": 568,
#         "os-rgbi:tile-number": 250,
#         "os-rgbi:tile-reference": "NT2267",
#         "os-rgbi:update-trigger": "Cyclic Revision Programme",
#         "proj:bbox": [
#             322000.0,
#             667000.0,
#             323000.0,
#             668000.0
#         ],
#         "proj:epsg": 27700,
#         "proj:geometry": {
#             "coordinates": [
#                 [
#                     [
#                         322000.0,
#                         667000.0
#                     ],
#                     [
#                         323000.0,
#                         667000.0
#                     ],
#                     [
#                         323000.0,
#                         668000.0
#                     ],
#                     [
#                         322000.0,
#                         668000.0
#                     ],
#                     [
#                         322000.0,
#                         667000.0
#                     ]
#                 ]
#             ],
#             "type": "Polygon"
#         },
#         "proj:projjson": {
#             "$schema": "https://proj.org/schemas/v0.4/projjson.schema.json",
#             "base_crs": {
#                 "coordinate_system": {
#                     "axis": [
#                         {
#                             "abbreviation": "Lat",
#                             "direction": "north",
#                             "name": "Geodetic latitude",
#                             "unit": "degree"
#                         },
#                         {
#                             "abbreviation": "Lon",
#                             "direction": "east",
#                             "name": "Geodetic longitude",
#                             "unit": "degree"
#                         }
#                     ],
#                     "subtype": "ellipsoidal"
#                 },
#                 "datum": {
#                     "ellipsoid": {
#                         "inverse_flattening": 299.3249646,
#                         "name": "Airy 1830",
#                         "semi_major_axis": 6377563.396
#                     },
#                     "name": "Ordnance Survey of Great Britain 1936",
#                     "type": "GeodeticReferenceFrame"
#                 },
#                 "id": {
#                     "authority": "EPSG",
#                     "code": 4277
#                 },
#                 "name": "OSGB36"
#             },
#             "conversion": {
#                 "method": {
#                     "id": {
#                         "authority": "EPSG",
#                         "code": 9807
#                     },
#                     "name": "Transverse Mercator"
#                 },
#                 "name": "unnamed",
#                 "parameters": [
#                     {
#                         "id": {
#                             "authority": "EPSG",
#                             "code": 8801
#                         },
#                         "name": "Latitude of natural origin",
#                         "unit": "degree",
#                         "value": 49
#                     },
#                     {
#                         "id": {
#                             "authority": "EPSG",
#                             "code": 8802
#                         },
#                         "name": "Longitude of natural origin",
#                         "unit": "degree",
#                         "value": -2
#                     },
#                     {
#                         "id": {
#                             "authority": "EPSG",
#                             "code": 8805
#                         },
#                         "name": "Scale factor at natural origin",
#                         "unit": "unity",
#                         "value": 0.9996012717
#                     },
#                     {
#                         "id": {
#                             "authority": "EPSG",
#                             "code": 8806
#                         },
#                         "name": "False easting",
#                         "unit": "metre",
#                         "value": 400000
#                     },
#                     {
#                         "id": {
#                             "authority": "EPSG",
#                             "code": 8807
#                         },
#                         "name": "False northing",
#                         "unit": "metre",
#                         "value": -100000
#                     }
#                 ]
#             },
#             "coordinate_system": {
#                 "axis": [
#                     {
#                         "abbreviation": "",
#                         "direction": "east",
#                         "name": "Easting",
#                         "unit": "metre"
#                     },
#                     {
#                         "abbreviation": "",
#                         "direction": "north",
#                         "name": "Northing",
#                         "unit": "metre"
#                     }
#                 ],
#                 "subtype": "Cartesian"
#             },
#             "id": {
#                 "authority": "EPSG",
#                 "code": 27700
#             },
#             "name": "OSGB36 / British National Grid",
#             "type": "ProjectedCRS"
#         },
#         "proj:shape": [
#             4000,
#             4000
#         ],
#         "proj:transform": [
#             0.25,
#             0.0,
#             322000.0,
#             0.0,
#             -0.25,
#             668000.0,
#             0.0,
#             0.0,
#             1.0
#         ]
#     },
#     "geometry": {
#         "coordinates": [
#             [
#                 [
#                     -3.248671843076596,
#                     55.88979302422307
#                 ],
#                 [
#                     -3.2479106920759295,
#                     55.88980074302747
#                 ],
#                 [
#                     -3.2471495407037723,
#                     55.889808457127714
#                 ],
#                 [
#                     -3.246388388960349,
#                     55.889816166523794
#                 ],
#                 [
#                     -3.245627236845887,
#                     55.88982387121572
#                 ],
#                 [
#                     -3.2448660843606123,
#                     55.88983157120345
#                 ],
#                 [
#                     -3.244104931504752,
#                     55.889839266487
#                 ],
#                 [
#                     -3.2433437782785326,
#                     55.88984695706638
#                 ],
#                 [
#                     -3.2425826246821767,
#                     55.88985464294158
#                 ],
#                 [
#                     -3.241821470715916,
#                     55.88986232411259
#                 ],
#                 [
#                     -3.2410603163799716,
#                     55.8898700005794
#                 ],
#                 [
#                     -3.240299161674573,
#                     55.889877672342
#                 ],
#                 [
#                     -3.239538006599945,
#                     55.8898853394004
#                 ],
#                 [
#                     -3.238776851156315,
#                     55.8898930017546
#                 ],
#                 [
#                     -3.238015695343908,
#                     55.88990065940456
#                 ],
#                 [
#                     -3.2372545391629504,
#                     55.88990831235032
#                 ],
#                 [
#                     -3.2364933826136713,
#                     55.88991596059185
#                 ],
#                 [
#                     -3.2357322256962924,
#                     55.889923604129145
#                 ],
#                 [
#                     -3.234971068411042,
#                     55.88993124296221
#                 ],
#                 [
#                     -3.2342099107581457,
#                     55.889938877091005
#                 ],
#                 [
#                     -3.233448752737831,
#                     55.88994650651559
#                 ],
#                 [
#                     -3.232687594350324,
#                     55.88995413123592
#                 ],
#                 [
#                     -3.232701158125286,
#                     55.89038188156132
#                 ],
#                 [
#                     -3.2327147222672274,
#                     55.89080963185463
#                 ],
#                 [
#                     -3.232728286776162,
#                     55.89123738211584
#                 ],
#                 [
#                     -3.2327418516521056,
#                     55.89166513234495
#                 ],
#                 [
#                     -3.23275541689507,
#                     55.89209288254199
#                 ],
#                 [
#                     -3.2327689825050703,
#                     55.892520632706905
#                 ],
#                 [
#                     -3.2327825484821164,
#                     55.89294838283975
#                 ],
#                 [
#                     -3.232796114826226,
#                     55.893376132940475
#                 ],
#                 [
#                     -3.2328096815374114,
#                     55.89380388300911
#                 ],
#                 [
#                     -3.2328232486156865,
#                     55.89423163304566
#                 ],
#                 [
#                     -3.2328368160610643,
#                     55.89465938305013
#                 ],
#                 [
#                     -3.232850383873558,
#                     55.895087133022486
#                 ],
#                 [
#                     -3.232863952053182,
#                     55.89551488296275
#                 ],
#                 [
#                     -3.232877520599951,
#                     55.895942632870934
#                 ],
#                 [
#                     -3.2328910895138767,
#                     55.89637038274702
#                 ],
#                 [
#                     -3.232904658794973,
#                     55.896798132591
#                 ],
#                 [
#                     -3.2329182284432534,
#                     55.89722588240289
#                 ],
#                 [
#                     -3.2329317984587327,
#                     55.89765363218271
#                 ],
#                 [
#                     -3.2329453688414227,
#                     55.8980813819304
#                 ],
#                 [
#                     -3.232958939591341,
#                     55.898509131646016
#                 ],
#                 [
#                     -3.232972510708497,
#                     55.898936881329554
#                 ],
#                 [
#                     -3.2337338448798802,
#                     55.89892925404896
#                 ],
#                 [
#                     -3.234495178683786,
#                     55.898921622062524
#                 ],
#                 [
#                     -3.235256512119985,
#                     55.898913985370285
#                 ],
#                 [
#                     -3.2360178451882535,
#                     55.898906343972236
#                 ],
#                 [
#                     -3.236779177888363,
#                     55.89889869786833
#                 ],
#                 [
#                     -3.2375405102200867,
#                     55.89889104705865
#                 ],
#                 [
#                     -3.238301842183202,
#                     55.89888339154316
#                 ],
#                 [
#                     -3.239063173777478,
#                     55.89887573132185
#                 ],
#                 [
#                     -3.239824505002691,
#                     55.89886806639477
#                 ],
#                 [
#                     -3.2405858358586137,
#                     55.898860396761904
#                 ],
#                 [
#                     -3.2413471663450184,
#                     55.89885272242322
#                 ],
#                 [
#                     -3.2421084964616824,
#                     55.89884504337879
#                 ],
#                 [
#                     -3.2428698262083753,
#                     55.89883735962858
#                 ],
#                 [
#                     -3.243631155584873,
#                     55.89882967117259
#                 ],
#                 [
#                     -3.244392484590949,
#                     55.89882197801083
#                 ],
#                 [
#                     -3.245153813226375,
#                     55.89881428014332
#                 ],
#                 [
#                     -3.2459151414909266,
#                     55.89880657757006
#                 ],
#                 [
#                     -3.246676469384377,
#                     55.898798870291046
#                 ],
#                 [
#                     -3.2474377969064996,
#                     55.89879115830629
#                 ],
#                 [
#                     -3.248199124057067,
#                     55.898783441615784
#                 ],
#                 [
#                     -3.2489604508358543,
#                     55.89877572021953
#                 ],
#                 [
#                     -3.248946703890162,
#                     55.89834797311263
#                 ],
#                 [
#                     -3.248932957316464,
#                     55.897920225973586
#                 ],
#                 [
#                     -3.248919211114744,
#                     55.89749247880239
#                 ],
#                 [
#                     -3.2489054652849902,
#                     55.89706473159902
#                 ],
#                 [
#                     -3.248891719827189,
#                     55.89663698436353
#                 ],
#                 [
#                     -3.248877974741326,
#                     55.896209237095874
#                 ],
#                 [
#                     -3.248864230027387,
#                     55.89578148979608
#                 ],
#                 [
#                     -3.24885048568536,
#                     55.895353742464124
#                 ],
#                 [
#                     -3.248836741715229,
#                     55.89492599510004
#                 ],
#                 [
#                     -3.24882299811698,
#                     55.89449824770378
#                 ],
#                 [
#                     -3.248809254890602,
#                     55.89407050027538
#                 ],
#                 [
#                     -3.248795512036079,
#                     55.89364275281483
#                 ],
#                 [
#                     -3.2487817695533985,
#                     55.89321500532212
#                 ],
#                 [
#                     -3.2487680274425452,
#                     55.892787257797266
#                 ],
#                 [
#                     -3.248754285703506,
#                     55.89235951024027
#                 ],
#                 [
#                     -3.248740544336268,
#                     55.89193176265111
#                 ],
#                 [
#                     -3.2487268033408156,
#                     55.8915040150298
#                 ],
#                 [
#                     -3.248713062717135,
#                     55.89107626737635
#                 ],
#                 [
#                     -3.248699322465216,
#                     55.89064851969076
#                 ],
#                 [
#                     -3.2486855825850407,
#                     55.89022077197299
#                 ],
#                 [
#                     -3.248671843076596,
#                     55.88979302422307
#                 ]
#             ]
#         ],
#         "type": "Polygon"
#     },
#     "links": [
#         {
#             "rel": "self",
#             "href": "https://os-eo-platform-rg-prod-apim.azure-api.net/stac/collections/os_rgbi/items/ffd85f2a-c3a1-4c81-9b25-7b059ba1f724",
#             "type": "application/json"
#         },
#         {
#             "rel": "collection",
#             "href": "https://os-eo-platform-rg-prod-apim.azure-api.net/stac/collections/os_rgbi",
#             "type": "application/json"
#         },
#         {
#             "rel": "parent",
#             "href": "https://os-eo-platform-rg-prod-apim.azure-api.net/stac/collections/os_rgbi",
#             "type": "application/json"
#         },
#         {
#             "rel": "root",
#             "href": "https://os-eo-platform-rg-prod-apim.azure-api.net/stac/collections/os_rgbi",
#             "type": "application/json",
#             "title": "OS RGBI 25cm Data"
#         },
#         {
#             "rel": "license",
#             "href": "https://www.ordnancesurvey.co.uk/business-government/tools-support/terms-conditions/os-open-data-licence",
#             "type": "license"
#         }
#     ],
#     "assets": {
#         "LOTH01_23-CMaskMap.txt": {
#             "href": "https://oseoinfraprodstrgacc.blob.core.windows.net/rss-rgbi25cm16bittiff-raw/data/incremental/2023/07/13/15/LOTH01_23-CMaskMap.txt?se=2023-09-16T14%3A21%3A10Z&sp=r&sv=2022-11-02&sr=b&sig=X51LqQuQKpgyGedGLFb4xtBey8rZx6ff7U3i6wmaV1c%3D",
#             "type": "text/plain"
#         },
#         "cmask": {
#             "href": "https://oseoinfraprodstrgacc.blob.core.windows.net/rss-rgbi25cm16bittiff-raw-cog/data/incremental/2023/07/13/15/LOTH01_23/NT2267-CMASK.tif?se=2023-09-16T14%3A21%3A10Z&sp=r&sv=2022-11-02&sr=b&sig=RtQD3MP1uATlhyNARRiLqTDN5x7gpfTPhHjyLmPpumk%3D",
#             "type": "image/tiff; application=geotiff; profile=cloud-optimized",
#             "eo:bands": [
#                 {
#                     "description": "red",
#                     "name": "b1"
#                 },
#                 {
#                     "description": "green",
#                     "name": "b2"
#                 },
#                 {
#                     "description": "blue",
#                     "name": "b3"
#                 }
#             ],
#             "raster:bands": [
#                 {
#                     "data_type": "uint8",
#                     "histogram": {
#                         "buckets": [
#                             940,
#                             464647,
#                             3154,
#                             1927,
#                             1990,
#                             3857,
#                             495725,
#                             4455,
#                             2309,
#                             69572
#                         ],
#                         "count": 11,
#                         "max": 220.0,
#                         "min": 0.0
#                     },
#                     "offset": 0.0,
#                     "sampling": "area",
#                     "scale": 1.0,
#                     "statistics": {
#                         "maximum": 220,
#                         "mean": 95.4292573928833,
#                         "minimum": 0,
#                         "stddev": 64.21532864617389,
#                         "valid_percent": 9.5367431640625e-05
#                     }
#                 },
#                 {
#                     "data_type": "uint8",
#                     "histogram": {
#                         "buckets": [
#                             488442,
#                             84284,
#                             3432,
#                             1745,
#                             1448,
#                             1308,
#                             1713,
#                             2485,
#                             452286,
#                             11433
#                         ],
#                         "count": 11,
#                         "max": 211.0,
#                         "min": 0.0
#                     },
#                     "offset": 0.0,
#                     "sampling": "area",
#                     "scale": 1.0,
#                     "statistics": {
#                         "maximum": 211,
#                         "mean": 96.51646614074707,
#                         "minimum": 0,
#                         "stddev": 82.97841566833537,
#                         "valid_percent": 9.5367431640625e-05
#                     }
#                 },
#                 {
#                     "data_type": "uint8",
#                     "histogram": {
#                         "buckets": [
#                             159,
#                             418,
#                             511,
#                             2146,
#                             572335,
#                             3935,
#                             3240,
#                             11546,
#                             454279,
#                             7
#                         ],
#                         "count": 11,
#                         "max": 236.0,
#                         "min": 0.0
#                     },
#                     "offset": 0.0,
#                     "sampling": "area",
#                     "scale": 1.0,
#                     "statistics": {
#                         "maximum": 236,
#                         "mean": 142.658540725708,
#                         "minimum": 0,
#                         "stddev": 41.51197876311728,
#                         "valid_percent": 9.5367431640625e-05
#                     }
#                 }
#             ],
#             "roles": []
#         },
#         "data": {
#             "href": "https://oseoinfraprodstrgacc.blob.core.windows.net/rss-rgbi25cm16bittiff-raw-cog/data/incremental/2023/07/13/15/LOTH01_23/NT2267.tif?se=2023-09-16T14%3A21%3A10Z&sp=r&sv=2022-11-02&sr=b&sig=BZZJMeqEWaAiCYtb32D1bqRNFBeJB5nbmIll6p8Wz4U%3D",
#             "type": "image/tiff; application=geotiff; profile=cloud-optimized",
#             "eo:bands": [
#                 {
#                     "description": "red",
#                     "name": "b1"
#                 },
#                 {
#                     "description": "green",
#                     "name": "b2"
#                 },
#                 {
#                     "description": "blue",
#                     "name": "b3"
#                 },
#                 {
#                     "description": "undefined",
#                     "name": "b4"
#                 }
#             ],
#             "raster:bands": [
#                 {
#                     "data_type": "uint16",
#                     "histogram": {
#                         "buckets": [
#                             852319,
#                             182118,
#                             11499,
#                             2439,
#                             150,
#                             30,
#                             11,
#                             6,
#                             2,
#                             2
#                         ],
#                         "count": 11,
#                         "max": 46694.0,
#                         "min": 1907.0
#                     },
#                     "offset": 0.0,
#                     "sampling": "area",
#                     "scale": 1.0,
#                     "statistics": {
#                         "maximum": 46694,
#                         "mean": 5172.421524047852,
#                         "minimum": 1907,
#                         "stddev": 1922.186152306457,
#                         "valid_percent": 9.5367431640625e-05
#                     }
#                 },
#                 {
#                     "data_type": "uint16",
#                     "histogram": {
#                         "buckets": [
#                             671565,
#                             368627,
#                             8003,
#                             301,
#                             33,
#                             28,
#                             9,
#                             6,
#                             2,
#                             2
#                         ],
#                         "count": 11,
#                         "max": 50634.0,
#                         "min": 3641.0
#                     },
#                     "offset": 0.0,
#                     "sampling": "area",
#                     "scale": 1.0,
#                     "statistics": {
#                         "maximum": 50634,
#                         "mean": 7547.011303901672,
#                         "minimum": 3641,
#                         "stddev": 1916.7438786342889,
#                         "valid_percent": 9.5367431640625e-05
#                     }
#                 },
#                 {
#                     "data_type": "uint16",
#                     "histogram": {
#                         "buckets": [
#                             1021069,
#                             24823,
#                             2541,
#                             62,
#                             42,
#                             22,
#                             7,
#                             6,
#                             2,
#                             2
#                         ],
#                         "count": 11,
#                         "max": 50061.0,
#                         "min": 4691.0
#                     },
#                     "offset": 0.0,
#                     "sampling": "area",
#                     "scale": 1.0,
#                     "statistics": {
#                         "maximum": 50061,
#                         "mean": 7094.141603469849,
#                         "minimum": 4691,
#                         "stddev": 1135.776746345702,
#                         "valid_percent": 9.5367431640625e-05
#                     }
#                 },
#                 {
#                     "data_type": "uint16",
#                     "histogram": {
#                         "buckets": [
#                             37267,
#                             73518,
#                             92783,
#                             128843,
#                             197303,
#                             316731,
#                             175936,
#                             21993,
#                             3983,
#                             219
#                         ],
#                         "count": 11,
#                         "max": 47178.0,
#                         "min": 5554.0
#                     },
#                     "offset": 0.0,
#                     "sampling": "area",
#                     "scale": 1.0,
#                     "statistics": {
#                         "maximum": 47178,
#                         "mean": 24553.475730895996,
#                         "minimum": 5554,
#                         "stddev": 6979.6422504023785,
#                         "valid_percent": 9.5367431640625e-05
#                     }
#                 }
#             ],
#             "roles": []
#         },
#         "metadata": {
#             "href": "https://oseoinfraprodstrgacc.blob.core.windows.net/rss-rgbi25cm16bittiff-raw/data/incremental/2023/07/13/15/LOTH01_23/NT2267.json?se=2023-09-16T14%3A21%3A10Z&sp=r&sv=2022-11-02&sr=b&sig=S12Zxl6fF2Vnpfg35en0ael0QP8JE0rTzqD8IHmK67U%3D",
#             "type": "application/json"
#         },
#         "rendered_hires_preview": {
#             "href": "https://oseoinfraprodstrgacc.blob.core.windows.net/rss-rgbi25cm16bittiff-raw-cog/data/incremental/2023/07/13/15/LOTH01_23/NT2267_thumbnail_hires.png?se=2023-09-16T14%3A21%3A10Z&sp=r&sv=2022-11-02&sr=b&sig=KdVG3I5xwkd9APRADbuQdV2MR0MHr2UhvI31WKwXvo4%3D",
#             "type": "image/png"
#         },
#         "rendered_hires_preview_cmask": {
#             "href": "https://oseoinfraprodstrgacc.blob.core.windows.net/rss-rgbi25cm16bittiff-raw-cog/data/incremental/2023/07/13/15/LOTH01_23/NT2267-CMASK_thumbnail_hires.png?se=2023-09-16T14%3A21%3A10Z&sp=r&sv=2022-11-02&sr=b&sig=fkRGOfISHfYw//k0sEamFFeGaUXynav1X/3/DlK8VyQ%3D",
#             "type": "image/png"
#         },
#         "rendered_preview": {
#             "href": "https://oseoinfraprodstrgacc.blob.core.windows.net/rss-rgbi25cm16bittiff-raw-cog/data/incremental/2023/07/13/15/LOTH01_23/NT2267_thumbnail.png?se=2023-09-16T14%3A21%3A10Z&sp=r&sv=2022-11-02&sr=b&sig=TL1sWZFK85auIKMNKStHDyvcbjP63UFgSD8IZ0Vk92g%3D",
#             "type": "image/png",
#             "title": "Rendered preview",
#             "rel": "preview",
#             "roles": [
#                 "overview"
#             ]
#         },
#         "rendered_preview_cmask": {
#             "href": "https://oseoinfraprodstrgacc.blob.core.windows.net/rss-rgbi25cm16bittiff-raw-cog/data/incremental/2023/07/13/15/LOTH01_23/NT2267-CMASK_thumbnail.png?se=2023-09-16T14%3A21%3A10Z&sp=r&sv=2022-11-02&sr=b&sig=5%2B%2BVCvFkHUGW/RthcWhGyNxHeJaJscRfpnrdKmI14y8%3D",
#             "type": "image/png"
#         }
#     },
#     "bbox": [
#         -3.2489604508358543,
#         55.88979302422307,
#         -3.232687594350324,
#         55.898936881329554
#     ],
#     "stac_extensions": [
#         "https://stac-extensions.github.io/projection/v1.1.0/schema.json",
#         "https://stac-extensions.github.io/raster/v1.1.0/schema.json",
#         "https://stac-extensions.github.io/eo/v1.1.0/schema.json",
#         "https://raw.githubusercontent.com/SpatialDays/sd-stac-extensions/main/os-rgbi/v1.0.1/schema.json",
#         "https://raw.githubusercontent.com/SpatialDays/sd-stac-extensions/main/bulk-upload-system-metadata/v1.0.1/schema.json"
#     ],
#     "collection": "os_rgbi"
# }
