# %%
# !pip install pystac
# !pip install pystac-client
# Out:
# Requirement already satisfied: pystac in ./env/lib/python3.10/site-packages (1.8.3)
# Requirement already satisfied: python-dateutil>=2.7.0 in ./env/lib/python3.10/site-packages (from pystac) (2.8.2)
# Requirement already satisfied: six>=1.5 in ./env/lib/python3.10/site-packages (from python-dateutil>=2.7.0->pystac) (1.16.0)
# Requirement already satisfied: pystac-client in ./env/lib/python3.10/site-packages (0.7.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./env/lib/python3.10/site-packages (from pystac-client) (2.8.2)
# Requirement already satisfied: requests>=2.28.2 in ./env/lib/python3.10/site-packages (from pystac-client) (2.31.0)
# Requirement already satisfied: pystac[validation]>=1.8.2 in ./env/lib/python3.10/site-packages (from pystac-client) (1.8.3)
# Requirement already satisfied: jsonschema<4.18,>=4.0.1 in ./env/lib/python3.10/site-packages (from pystac[validation]>=1.8.2->pystac-client) (4.17.3)
# Requirement already satisfied: six>=1.5 in ./env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pystac-client) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in ./env/lib/python3.10/site-packages (from requests>=2.28.2->pystac-client) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./env/lib/python3.10/site-packages (from requests>=2.28.2->pystac-client) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./env/lib/python3.10/site-packages (from requests>=2.28.2->pystac-client) (2023.7.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./env/lib/python3.10/site-packages (from requests>=2.28.2->pystac-client) (3.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in ./env/lib/python3.10/site-packages (from jsonschema<4.18,>=4.0.1->pystac[validation]>=1.8.2->pystac-client) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in ./env/lib/python3.10/site-packages (from jsonschema<4.18,>=4.0.1->pystac[validation]>=1.8.2->pystac-client) (23.1.0)

# %%
import pystac
import pystac_client
import random
import folium
from typing import Dict, List

# %%
# Credentials and details for Azure APIM
APIM_STAC_URL = "https://os-eo-platform-rg-prod-apim.azure-api.net/stac"
APIM_AUTH_TOKEN = "d208843ea70a43d29416315322dc3228"
# Create AUTH Header object
auth_headers = {"ocp-apim-subscription-key": APIM_AUTH_TOKEN}

# %%
# Create Pystac client object
client: pystac_client.client.Client = pystac_client.Client.from_file(
    APIM_STAC_URL, headers=auth_headers
)

# %%
# Filter items
cql_filter_dict: Dict[str, str] = {
    "op": "=",
    "args": [{"property": "os-heightstore-dtm1m:dtm-grid-id"}, "76550c42-a249-3295-7b97-b97998c8233b"],
}
items: pystac.ItemCollection = client.search(
    max_items=100, filter=cql_filter_dict
)
for item in items.item_collection():
    item: pystac.Item = item
    print(item.id)
# Out:
# b51f8b58-baf4-2a5d-bb44-7b2c52b74698-DTM-09-09
# b51f8b58-baf4-2a5d-bb44-7b2c52b74698-DTM-09-08
# b51f8b58-baf4-2a5d-bb44-7b2c52b74698-DTM-09-07
# b51f8b58-baf4-2a5d-bb44-7b2c52b74698-DTM-09-03
# b51f8b58-baf4-2a5d-bb44-7b2c52b74698-DTM-09-02
# b51f8b58-baf4-2a5d-bb44-7b2c52b74698-DTM-09-06
# b51f8b58-baf4-2a5d-bb44-7b2c52b74698-DTM-09-05
# b51f8b58-baf4-2a5d-bb44-7b2c52b74698-DTM-09-04
# b51f8b58-baf4-2a5d-bb44-7b2c52b74698-DTM-09-01
# b51f8b58-baf4-2a5d-bb44-7b2c52b74698-DTM-09-00
# b51f8b58-baf4-2a5d-bb44-7b2c52b74698-DTM-08-09
# b51f8b58-baf4-2a5d-bb44-7b2c52b74698-DTM-08-06
bbox_for_map: Dict = (
    first_item.bbox[1],
    first_item.bbox[0],
    first_item.bbox[3],
    first_item.bbox[2],
)
print(bbox_for_map)

folium_map: folium.Map = folium.Map(
    tiles="OpenStreetMap", zoom_start=11, location=[bbox_for_map[0], bbox_for_map[1]]
)


def random_color() -> str:
    return "#{:06x}".format(random.randint(0, 0xFFFFFF))


for item in items.item_collection():
    item: pystac.Item = item
    bbox: Dict = (item.bbox[1], item.bbox[0], item.bbox[3], item.bbox[2])
    # map bbox on folium map
    folium.Rectangle(
        bounds=[[bbox[0], bbox[1]], [bbox[2], bbox[3]]],
        fill=False,
        tooltip=item.id,
        fill_color=random_color(),
        popup=item.id,
    ).add_to(folium_map)

folium_map
# Out:
# (56.34516519803554, -4.1215880189824246, 56.3544190595798, -4.104922438338921)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c51c3d12dde5343a5511f8fd433814a1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c51c3d12dde5343a5511f8fd433814a1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c51c3d12dde5343a5511f8fd433814a1 = L.map(
#                 &quot;map_c51c3d12dde5343a5511f8fd433814a1&quot;,
#                 {
#                     center: [56.34516519803554, -4.1215880189824246],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_13f6257df8ec0c79a3bd1784f522f04a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c51c3d12dde5343a5511f8fd433814a1);
#
#
#             var rectangle_ff17f27ae8221bda90fbbac583e24314 = L.rectangle(
#                 [[56.34516519803554, -4.1215880189824246], [56.3544190595798, -4.104922438338921]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#567ebd&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c51c3d12dde5343a5511f8fd433814a1);
#
#
#         var popup_829fa35d7e90898ba9fa8e96b59e9005 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e2a3e0f0558d37d3e8053fa506b013d6 = $(`&lt;div id=&quot;html_e2a3e0f0558d37d3e8053fa506b013d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;b51f8b58-baf4-2a5d-bb44-7b2c52b74698-DTM-09-09&lt;/div&gt;`)[0];
#                 popup_829fa35d7e90898ba9fa8e96b59e9005.setContent(html_e2a3e0f0558d37d3e8053fa506b013d6);
#
#
#
#         rectangle_ff17f27ae8221bda90fbbac583e24314.bindPopup(popup_829fa35d7e90898ba9fa8e96b59e9005)
#         ;
#
#
#
#
#             rectangle_ff17f27ae8221bda90fbbac583e24314.bindTooltip(
#                 `&lt;div&gt;
#                      b51f8b58-baf4-2a5d-bb44-7b2c52b74698-DTM-09-09
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var rectangle_3d27eac8686994037df1197b62806da5 = L.rectangle(
#                 [[56.33618717894671, -4.12108940389694], [56.345440963314864, -4.104427900354041]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#2c45f0&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c51c3d12dde5343a5511f8fd433814a1);
#
#
#         var popup_6380ca5b8d72799543fbbecd0dcc7dc6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_025bcf1893a01fdaecdf5b0c2f61af14 = $(`&lt;div id=&quot;html_025bcf1893a01fdaecdf5b0c2f61af14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;b51f8b58-baf4-2a5d-bb44-7b2c52b74698-DTM-09-08&lt;/div&gt;`)[0];
#                 popup_6380ca5b8d72799543fbbecd0dcc7dc6.setContent(html_025bcf1893a01fdaecdf5b0c2f61af14);
#
#
#
#         rectangle_3d27eac8686994037df1197b62806da5.bindPopup(popup_6380ca5b8d72799543fbbecd0dcc7dc6)
#         ;
#
#
#
#
#             rectangle_3d27eac8686994037df1197b62806da5.bindTooltip(
#                 `&lt;div&gt;
#                      b51f8b58-baf4-2a5d-bb44-7b2c52b74698-DTM-09-08
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var rectangle_f322b67b9d86eac2df6521cc201119c9 = L.rectangle(
#                 [[56.327209143873525, -4.120591074971888], [56.33646285110864, -4.103933646133469]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#36dc82&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c51c3d12dde5343a5511f8fd433814a1);
