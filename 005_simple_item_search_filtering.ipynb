# %%
# !pip install pystac
# !pip install pystac-client
# Out:
# Requirement already satisfied: pystac in ./env/lib/python3.10/site-packages (1.8.3)
# Requirement already satisfied: python-dateutil>=2.7.0 in ./env/lib/python3.10/site-packages (from pystac) (2.8.2)
# Requirement already satisfied: six>=1.5 in ./env/lib/python3.10/site-packages (from python-dateutil>=2.7.0->pystac) (1.16.0)
# Requirement already satisfied: pystac-client in ./env/lib/python3.10/site-packages (0.7.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./env/lib/python3.10/site-packages (from pystac-client) (2.8.2)
# Requirement already satisfied: pystac[validation]>=1.8.2 in ./env/lib/python3.10/site-packages (from pystac-client) (1.8.3)
# Requirement already satisfied: requests>=2.28.2 in ./env/lib/python3.10/site-packages (from pystac-client) (2.31.0)
# Requirement already satisfied: jsonschema<4.18,>=4.0.1 in ./env/lib/python3.10/site-packages (from pystac[validation]>=1.8.2->pystac-client) (4.17.3)
# Requirement already satisfied: six>=1.5 in ./env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pystac-client) (1.16.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./env/lib/python3.10/site-packages (from requests>=2.28.2->pystac-client) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in ./env/lib/python3.10/site-packages (from requests>=2.28.2->pystac-client) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./env/lib/python3.10/site-packages (from requests>=2.28.2->pystac-client) (2023.7.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./env/lib/python3.10/site-packages (from requests>=2.28.2->pystac-client) (3.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in ./env/lib/python3.10/site-packages (from jsonschema<4.18,>=4.0.1->pystac[validation]>=1.8.2->pystac-client) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in ./env/lib/python3.10/site-packages (from jsonschema<4.18,>=4.0.1->pystac[validation]>=1.8.2->pystac-client) (23.1.0)

# %%
import pystac
import pystac_client
import random
import folium
from typing import Dict, List

# %%
# Credentials and details for Azure APIM
APIM_STAC_URL = "https://os-eo-platform-rg-prod-apim.azure-api.net/stac"
APIM_AUTH_TOKEN = "d208843ea70a43d29416315322dc3228"
# Create AUTH Header object
auth_headers = {"ocp-apim-subscription-key": APIM_AUTH_TOKEN}

# %%
# Create Pystac client object
client: pystac_client.client.Client = pystac_client.Client.from_file(
    APIM_STAC_URL, headers=auth_headers
)

# %%
# Filter items by collection and bbox, limit to 10 items
COLLECTION_ID = "os_rgbi"
collection: pystac.Collection = client.get_collection(COLLECTION_ID)
bbox: List[float] = [-3.911, 52.176, -3.753, 52.256]
items: pystac.ItemCollection = client.search(
    max_items=20,
    collections=[COLLECTION_ID],
    bbox=bbox,
)
for item in items.item_collection():
    item: pystac.Item = item
    print(item.id)
# Out:
# fea01a98-9b91-49a5-a2c4-96d1faabbec3
# fd86ad85-2835-4e43-a24d-586234d0c5e5
# fd33d1fe-5775-4e00-be2a-f492aebb7511
# e1b9f9a5-f86b-46de-b315-86db31580596
# a968542f-7ae1-4520-af14-35ac246c3ca6
# 86e85469-ab18-4e60-b4d3-f2efad292bbb
# 6c34b107-7472-417c-baa6-31a6d9b364b4
# 67248e32-dba6-46f3-8761-f1ace9abe63f
# 622e9bb8-c5e6-42c5-bdaa-be150e0c2ea2
# 6142b0a4-e541-4c6e-ade6-16772f85b7df
# 33d9ca9a-e3e2-4b3a-96b3-40b2b27da0d8
# 23bed74f-85f5-496e-b8f6-b619bbe76bd9

# %%
# plot all item bboxes on a map
first_item: pystac.Item = items.item_collection()[0]

bbox_for_map: Dict = (
    first_item.bbox[1],
    first_item.bbox[0],
    first_item.bbox[3],
    first_item.bbox[2],
)
print(bbox_for_map)

folium_map: folium.Map = folium.Map(
    tiles="OpenStreetMap", zoom_start=14, location=[bbox_for_map[0], bbox_for_map[1]]
)


def random_color() -> str:
    return "#{:06x}".format(random.randint(0, 0xFFFFFF))


for item in items.item_collection():
    item: pystac.Item = item
    bbox: Dict = (item.bbox[1], item.bbox[0], item.bbox[3], item.bbox[2])
    # map bbox on folium map
    folium.Rectangle(
        bounds=[[bbox[0], bbox[1]], [bbox[2], bbox[3]]],
        fill=False,
        tooltip=item.id,
        fill_color=random_color(),
        popup=item.id,
    ).add_to(folium_map)

folium_map
# Out:
# (52.21453351626617, -3.860668460852561, 52.22374897991374, -3.8456642721012573)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f5f85edfdb7aa8340ebcd436fcfe12a3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f5f85edfdb7aa8340ebcd436fcfe12a3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f5f85edfdb7aa8340ebcd436fcfe12a3 = L.map(
#                 &quot;map_f5f85edfdb7aa8340ebcd436fcfe12a3&quot;,
#                 {
#                     center: [52.21453351626617, -3.860668460852561],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9cd6171f588fa6aa475ff3b191cbb9dc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f5f85edfdb7aa8340ebcd436fcfe12a3);
#
#
#             var rectangle_16dc8f0035f5f58b8a317f6c8c4c133a = L.rectangle(
#                 [[52.21453351626617, -3.860668460852561], [52.22374897991374, -3.8456642721012573]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#029745&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f5f85edfdb7aa8340ebcd436fcfe12a3);
#
#
#         var popup_a3f0ded61c7941dd1f6fef35bd0b9940 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9577eb82a3aaccd675b46397643102ab = $(`&lt;div id=&quot;html_9577eb82a3aaccd675b46397643102ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;fea01a98-9b91-49a5-a2c4-96d1faabbec3&lt;/div&gt;`)[0];
#                 popup_a3f0ded61c7941dd1f6fef35bd0b9940.setContent(html_9577eb82a3aaccd675b46397643102ab);
#
#
#
#         rectangle_16dc8f0035f5f58b8a317f6c8c4c133a.bindPopup(popup_a3f0ded61c7941dd1f6fef35bd0b9940)
#         ;
#
#
#
#
#             rectangle_16dc8f0035f5f58b8a317f6c8c4c133a.bindTooltip(
#                 `&lt;div&gt;
#                      fea01a98-9b91-49a5-a2c4-96d1faabbec3
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var rectangle_188fbf680b97c036fda77a40982a231d = L.rectangle(
#                 [[52.2161038943201, -3.75824396910449], [52.225307171221594, -3.7432590917828596]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#017fde&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f5f85edfdb7aa8340ebcd436fcfe12a3);
#
#
#         var popup_74a3679a1bf4def1abec093924d736b4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a60cde7698ee459e4df77c42c939c742 = $(`&lt;div id=&quot;html_a60cde7698ee459e4df77c42c939c742&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;fd86ad85-2835-4e43-a24d-586234d0c5e5&lt;/div&gt;`)[0];
#                 popup_74a3679a1bf4def1abec093924d736b4.setContent(html_a60cde7698ee459e4df77c42c939c742);
#
#
#
#         rectangle_188fbf680b97c036fda77a40982a231d.bindPopup(popup_74a3679a1bf4def1abec093924d736b4)
#         ;
#
#
#
#
#             rectangle_188fbf680b97c036fda77a40982a231d.bindTooltip(
#                 `&lt;div&gt;
#                      fd86ad85-2835-4e43-a24d-586234d0c5e5
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var rectangle_9ca2513a0289df622c410a578281ad0f = L.rectangle(
#                 [[52.213596283833915, -3.9191924340457565], [52.222818697294464, -3.904177247213249]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#7fbc83&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f5f85edfdb7aa8340ebcd436fcfe12a3);
#
#
#         var popup_d605015f4db4fca418ad
