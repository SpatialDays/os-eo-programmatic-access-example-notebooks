# %%
# !pip install pystac
# !pip install pystac-client
# Out:
# Requirement already satisfied: pystac in ./env/lib/python3.10/site-packages (1.8.3)
# Requirement already satisfied: python-dateutil>=2.7.0 in ./env/lib/python3.10/site-packages (from pystac) (2.8.2)
# Requirement already satisfied: six>=1.5 in ./env/lib/python3.10/site-packages (from python-dateutil>=2.7.0->pystac) (1.16.0)
# Requirement already satisfied: pystac-client in ./env/lib/python3.10/site-packages (0.7.5)
# Requirement already satisfied: pystac[validation]>=1.8.2 in ./env/lib/python3.10/site-packages (from pystac-client) (1.8.3)
# Requirement already satisfied: requests>=2.28.2 in ./env/lib/python3.10/site-packages (from pystac-client) (2.31.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./env/lib/python3.10/site-packages (from pystac-client) (2.8.2)
# Requirement already satisfied: jsonschema<4.18,>=4.0.1 in ./env/lib/python3.10/site-packages (from pystac[validation]>=1.8.2->pystac-client) (4.17.3)
# Requirement already satisfied: six>=1.5 in ./env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pystac-client) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./env/lib/python3.10/site-packages (from requests>=2.28.2->pystac-client) (2023.7.22)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./env/lib/python3.10/site-packages (from requests>=2.28.2->pystac-client) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in ./env/lib/python3.10/site-packages (from requests>=2.28.2->pystac-client) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./env/lib/python3.10/site-packages (from requests>=2.28.2->pystac-client) (3.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in ./env/lib/python3.10/site-packages (from jsonschema<4.18,>=4.0.1->pystac[validation]>=1.8.2->pystac-client) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in ./env/lib/python3.10/site-packages (from jsonschema<4.18,>=4.0.1->pystac[validation]>=1.8.2->pystac-client) (23.1.0)

# %%
import pystac
import pystac_client
import random
import folium
from typing import Dict, List

# %%
# Credentials and details for Azure APIM
APIM_STAC_URL = "https://os-eo-platform-rg-prod-apim.azure-api.net/stac"
APIM_AUTH_TOKEN = "d208843ea70a43d29416315322dc3228"
# Create AUTH Header object
auth_headers = {"ocp-apim-subscription-key": APIM_AUTH_TOKEN}

# %%
# Create Pystac client object
client: pystac_client.client.Client = pystac_client.Client.from_file(
    APIM_STAC_URL, headers=auth_headers
)

# %%
# Filter items
COLLECTION_ID = "os_rgbi"
bbox: List[float] = [-3.911, 52.176, -3.753, 52.256]

cql_filter_dict: Dict[str, str] = {
    "op": "=",
    "args": [{"property": "os-rgbi:flying-block"}, "DEVON01_21"],
}
items: pystac.ItemCollection = client.search(
    max_items=100, collections=[COLLECTION_ID], filter=cql_filter_dict
)
for item in items.item_collection():
    item: pystac.Item = item
    print(item.id)
# Out:
# fdcd6488-6e3d-4889-83a5-9ba877e40e59
# f6f9361b-fd76-4189-9740-2fe7a9097597
# f62b28f0-b3cb-4291-912b-9873fd94a686
# f139e508-b534-4e6a-8e28-947db8c1023a
# cee5c210-d97b-42d2-9757-3db90a2900a4
# ca6d68c6-fdba-4b24-bbb3-dd266d4d07ca
# ca0f1d39-e5bd-4380-9dde-cec3b44afafd
# a3b250fe-eddf-4858-a113-ad08dc7ed051
# a334da4e-f379-46a7-935b-93fe13584580
# a1fae379-eb0f-4f81-91ab-f93c37c92c93
# 9bcd6924-dd12-454f-aedf-0ee06fab1b39
# 9a1cb3c5-e0df-4c2e-b9be-43922b8b15ae
# 9097de28-b630-42c4-a51c-f22538d49b0c
# 8c81c6e3-0e35-43d9-9f75-99ae77263db8
# 8b4acb51-a1f4-4224-b5d5-e80c9027fc93
# 8a722a20-3501-4468-b32a-823a8d29e64b
# 878e33b9-4b37-49d9-b716-3557ab00c6ce
# 86bea9e9-368c-41f6-9d39-67f56edefb40
# 86b38bf5-3e89-4d6d-a2ac-703b0c65079c
# 85c2c3e8-276c-4c08-b4f7-03566870debe
# 8421ae4b-137e-46c0-8190-f655bc42bb9c
# 8236eb46-633a-48a2-a09c-d6cd9008ac84
# 81d05fd4-a7d4-4e9b-915a-9b01c9debf89
# 80b3822c-e325-4932-a7fa-7dc7351bf45e
# 7f6facc7-7d81-433c-82e0-4f5bdd98ecd1
# 7e74b067-4b07-40bf-8bc1-a6775764784a
# 7a560178-75f2-429a-be18-2de5a87d25b6
# 7a3b004c-345d-4af3-8cdf-66842f891832
# 77bb3bee-9598-4f4d-a96b-3c492d02cc41
# 707ea8d0-09f7-4173-a514-b5c4e0bce54f
# 6b241c83-1f7e-4d03-9af0-7813c6bf3d3c
# 6a1834ff-e627-4570-9e73-2f882d1dcf62
# 68514ca8-b1d8-4b5b-9f12-2b4b85d7fb46
# 64e0ca7c-b36e-4f8a-abd9-faf26b98ba19
# 6481d005-3d7c-4932-a6eb-0ee04e143e91
# 647c9acd-b6d1-4a31-9786-3f495d1551d1
# 63e834d4-4c70-4a9d-80a5-39fa2a28351e
# 60e82e1b-525c-4f9a-adcc-780504e407d3
# 60999c07-6483-4446-87fb-af9aa4674cee
# 6046022c-21cf-43bb-803b-4a4e0fd577be
# 5e6198c3-6882-4205-a423-9b528a707bcb
# 5dd3d978-c00e-4903-9f10-9137c815f830
# 5d9af771-87a2-45fa-8b77-bb0d04f610e5
# 5a428d45-8bdf-4dc5-8a90-f248336aa013
# 56df3358-44e2-4ca9-b729-5b055bd053cd
# 55a3ff95-7c6b-4083-b78a-7c556d09d24d
# 55092fef-8825-485f-960c-17a67930b410
# 50fa97fb-51ab-4aa5-8d5b-f9111d7f064a

# %%
# plot all item bboxes on a map
first_item: pystac.Item = items.item_collection()[0]

bbox_for_map: Dict = (
    first_item.bbox[1],
    first_item.bbox[0],
    first_item.bbox[3],
    first_item.bbox[2],
)
print(bbox_for_map)

folium_map: folium.Map = folium.Map(
    tiles="OpenStreetMap", zoom_start=11, location=[bbox_for_map[0], bbox_for_map[1]]
)


def random_color() -> str:
    return "#{:06x}".format(random.randint(0, 0xFFFFFF))


for item in items.item_collection():
    item: pystac.Item = item
    bbox: Dict = (item.bbox[1], item.bbox[0], item.bbox[3], item.bbox[2])
    # map bbox on folium map
    folium.Rectangle(
        bounds=[[bbox[0], bbox[1]], [bbox[2], bbox[3]]],
        fill=False,
        tooltip=item.id,
        fill_color=random_color(),
        popup=item.id,
    ).add_to(folium_map)

folium_map
# Out:
# (50.763595277488605, -3.447915699623931, 50.77276018797942, -3.433463756706805)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c5b67d4ce92cf17a24bd182e22a4b0aa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c5b67d4ce92cf17a24bd182e22a4b0aa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c5b67d4ce92cf17a24bd182e22a4b0aa = L.map(
#                 &quot;map_c5b67d4ce92cf17a24bd182e22a4b0aa&quot;,
#                 {
#                     center: [50.763595277488605, -3.447915699623931],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_86af2aea29541ce16fce0aa92b2af541 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c5b67d4ce92cf17a24bd182e22a4b0aa);
#
#
#             var rectangle_52d4cf3320984a274c47a5de70015340 = L.rectangle(
#                 [[50.763595277488605, -3.447915699623931], [50.77276018797942, -3.433463756706805]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#5aaa9b&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c5b67d4ce92cf17a24bd182e22a4b0aa);
#
#
#         var popup_16c149affd638a4bf78459f081afb43e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b442991723cc1e17a4fddd73f9db0974 = $(`&lt;div id=&quot;html_b442991723cc1e17a4fddd73f9db0974&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;fdcd6488-6e3d-4889-83a5-9ba877e40e59&lt;/div&gt;`)[0];
#                 popup_16c149affd638a4bf78459f081afb43e.setContent(html_b442991723cc1e17a4fddd73f9db0974);
#
#
#
#         rectangle_52d4cf3320984a274c47a5de70015340.bindPopup(popup_16c149affd638a4bf78459f081afb43e)
#         ;
#
#
#
#
#             rectangle_52d4cf3320984a274c47a5de70015340.bindTooltip(
#                 `&lt;div&gt;
#                      fdcd6488-6e3d-4889-83a5-9ba877e40e59
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var rectangle_4a2bb91da4d1f2df3bd30f9cece7a58c = L.rectangle(
#                 [[50.76194159114563, -3.575502981780397], [50.771121477651576, -3.561027935607703]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#43a79f&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c5b67d4ce92cf17a24bd182e22a4b0aa);
#
#
#         var popup_e9bc7367125cc80c939c74cc6428f092 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ecebf1a7bc9f63388c4bf073c2a3babb = $(`&lt;div id=&quot;html_ecebf1a7bc9f63388c4bf073c2a3babb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;f6f9361b-fd76-4189-9740-2fe7a9097597&lt;/div&gt;`)[0];
#                 popup_e9bc7367125cc80c939c74cc6428f092.setContent(html_ecebf1a7bc9f63388c4bf073c2a3babb);
#
#
#
#         rectangle_4a2bb91da4d1f2df3bd30f9cece7a58c.bindPopup(popup_e9bc7367125cc80c939c74cc6428f092)
#         ;
#
#
#
#
#             rectangle_4a2bb91da4d1f2df3bd30f9cece7a58c.bindTooltip(
#                 `&lt;div&gt;
#                      f6f9361b-fd76-4189-9740-2fe7a9097597
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var rectangle_8c847ab1013ad3915ff1eb1e7c929572 = L.rectangle(
#                 [[50.76174923906461, -3.589678592558347], [50.77093078661901, -3.5752009867929684]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#575595&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c5b67d4ce92cf17a24bd182e22a4b0aa);
#
#
#         var popup_d54f2f39a85ce3ac2883
